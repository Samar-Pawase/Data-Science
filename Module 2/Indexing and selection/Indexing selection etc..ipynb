# %%
# Importing lib
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of           ID  Clump_Thickness  Cell_Size_Uniformity  Cell_Shape_Uniformity  \
# 0    1000025                5                     1                      1
# 1    1002945                5                     4                      4
# 2    1015425                3                     1                      1
# 3    1016277                6                     8                      8
# 4    1017023                4                     1                      1
# ..       ...              ...                   ...                    ...
# 694   776715                3                     1                      1
# 695   841769                2                     1                      1
# 696   888820                5                    10                     10
# 697   897471                4                     8                      6
# 698   897471                4                     8                      8
#
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of           ID  Clump_Thickness  Cell_Size_Uniformity  Cell_Shape_Uniformity  \
# 0    1000025                5                     1                      1
# 1    1002945                5                     4                      4
# 2    1015425                3                     1                      1
# 3    1016277                6                     8                      8
# 4    1017023                4                     1                      1
# ..       ...              ...                   ...                    ...
# 694   776715                3                     1                      1
# 695   841769                2                     1                      1
# 696   888820                5                    10                     10
# 697   897471                4                     8                      6
# 698   897471                4                     8                      8
#
# ...

# %%
# Accessing specific columns by names
df[['Clump_Thickness','Cell_Shape_Uniformity']]
# Out:
#      Clump_Thickness  Cell_Shape_Uniformity
# 0                  5                      1
# 1                  5                      4
# 2                  3                      1
# 3                  6                      8
# 4                  4                      1
# ..               ...                    ...
# 694                3                      1
# 695                2                      1
# 696                5                     10
# 697                4                      6
# 698                4                      8
#
# [699 rows x 2 columns]

# %%
# Accessing specific rws by their positions
# To select first 7 rows
df.iloc[:7]
# Out:
#         ID  Clump_Thickness  Cell_Size_Uniformity  Cell_Shape_Uniformity  \
# 0  1000025                5                     1                      1
# 1  1002945                5                     4                      4
# 2  1015425                3                     1                      1
# 3  1016277                6                     8                      8
# 4  1017023                4                     1                      1
# 5  1017122                8                    10                     10
# 6  1018099                1                     1                      1
#
#    Marginal_Adhesion  Single_Epithelial_Cell_Size Bare_Nuclei  \
# 0                  1                          2.0           1
# 1                  5                          NaN          10
# 2                  1                          2.0           2
# 3                  1                          3.0           4
# 4                  3                          2.0           1
# ...

# %%
# Accessing col using iloc
df.iloc[:,:2]
# Out:
#           ID  Clump_Thickness
# 0    1000025                5
# 1    1002945                5
# 2    1015425                3
# 3    1016277                6
# 4    1017023                4
# ..       ...              ...
# 694   776715                3
# 695   841769                2
# 696   888820                5
# 697   897471                4
# 698   897471                4
#
# [699 rows x 2 columns]

# %%
# Accessing data frame according to a certian condition
df[df['Clump_Thickness']==3] #Accessing all the rows having clump thickness 3
# Out:
#           ID  Clump_Thickness  Cell_Size_Uniformity  Cell_Shape_Uniformity  \
# 2    1015425                3                     1                      1
# 22   1056784                3                     1                      1
# 26   1066373                3                     2                      1
# 30   1070935                3                     1                      1
# 34   1075123                3                     1                      2
# ..       ...              ...                   ...                    ...
# 671  1353092                3                     2                      1
# 687   566346                3                     1                      1
# 692   714039                3                     1                      1
# 693   763235                3                     1                      1
# 694   776715                3                     1                      1
#
#      Marginal_Adhesion  Single_Epithelial_Cell_Size Bare_Nuclei  \
# ...
